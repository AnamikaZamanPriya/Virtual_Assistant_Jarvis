# %%
pip install SpeechRecognition
# Out:
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.8.1-py2.py3-none-any.whl (32.8 MB)
# Installing collected packages: SpeechRecognition
# Successfully installed SpeechRecognition-3.8.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyttsx3
# Out:
# Collecting pyttsx3
#   Downloading pyttsx3-2.90-py3-none-any.whl (39 kB)
# Requirement already satisfied: pywin32; platform_system == "Windows" in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3) (227)
# Requirement already satisfied: comtypes; platform_system == "Windows" in c:\users\hp\anaconda3\lib\site-packages (from pyttsx3) (1.1.7)
# Collecting pypiwin32; platform_system == "Windows"
#   Downloading pypiwin32-223-py3-none-any.whl (1.7 kB)
# Installing collected packages: pypiwin32, pyttsx3
# Successfully installed pypiwin32-223 pyttsx3-2.90
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c anaconda pyaudio
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\HP\anaconda3
#
#   added / updated specs:
#     - pyaudio
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2020.10.14 |                0         159 KB  anaconda
#     conda-4.10.1               |   py38haa95532_1         2.9 MB
#     openssl-1.1.1h             |       he774522_0         5.8 MB  anaconda
#     portaudio-19.6.0           |       he774522_4         240 KB  anaconda
#     pyaudio-0.2.11             |   py38he774522_2         189 KB  anaconda
#     ------------------------------------------------------------
#                                            Total:         9.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   portaudio          anaconda/win-64::portaudio-19.6.0-he774522_4
#   pyaudio            anaconda/win-64::pyaudio-0.2.11-py38he774522_2
#
# The following packages will be UPDATED:
#
#   conda                                4.9.2-py38haa95532_0 --> 4.10.1-py38haa95532_1
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   ca-certificates                                 pkgs/main --> anaconda
#   openssl                                         pkgs/main --> anaconda
#
#
#
# Downloading and Extracting Packages
#
# ca-certificates-2020 | 159 KB    |            |   0%
# ca-certificates-2020 | 159 KB    | #          |  10%
# ca-certificates-2020 | 159 KB    | #######    |  70%
# ca-certificates-2020 | 159 KB    | ########## | 100%
# ca-certificates-2020 | 159 KB    | ########## | 100%
#
# portaudio-19.6.0     | 240 KB    |            |   0%
# portaudio-19.6.0     | 240 KB    | 6          |   7%
# portaudio-19.6.0     | 240 KB    | ##6        |  27%
# portaudio-19.6.0     | 240 KB    | #####3     |  53%
# portaudio-19.6.0     | 240 KB    | #########3 |  93%
# portaudio-19.6.0     | 240 KB    | ########## | 100%
#
# pyaudio-0.2.11       | 189 KB    |            |   0%
# pyaudio-0.2.11       | 189 KB    | 8          |   8%
# pyaudio-0.2.11       | 189 KB    | ###3       |  34%
# pyaudio-0.2.11       | 189 KB    | #######6   |  76%
# pyaudio-0.2.11       | 189 KB    | ########## | 100%
#
# openssl-1.1.1h       | 5.8 MB    |            |   0%
# openssl-1.1.1h       | 5.8 MB    |            |   0%
# openssl-1.1.1h       | 5.8 MB    | 1          |   2%
# openssl-1.1.1h       | 5.8 MB    | 2          |   3%
# openssl-1.1.1h       | 5.8 MB    | 3          |   4%
# openssl-1.1.1h       | 5.8 MB    | 4          |   4%
# openssl-1.1.1h       | 5.8 MB    | 7          |   7%
# openssl-1.1.1h       | 5.8 MB    | 8          |   8%
# openssl-1.1.1h       | 5.8 MB    | #          |  11%
# openssl-1.1.1h       | 5.8 MB    | #1         |  12%
# openssl-1.1.1h       | 5.8 MB    | #3         |  13%
# openssl-1.1.1h       | 5.8 MB    | #6         |  16%
# openssl-1.1.1h       | 5.8 MB    | #7         |  18%
# openssl-1.1.1h       | 5.8 MB    | #9         |  19%
# openssl-1.1.1h       | 5.8 MB    | ##         |  21%
# openssl-1.1.1h       | 5.8 MB    | ##2        |  22%
# openssl-1.1.1h       | 5.8 MB    | ##3        |  24%
# openssl-1.1.1h       | 5.8 MB    | ##4        |  25%
# openssl-1.1.1h       | 5.8 MB    | ##6        |  27%
# openssl-1.1.1h       | 5.8 MB    | ##7        |  28%
# openssl-1.1.1h       | 5.8 MB    | ##8        |  29%
# openssl-1.1.1h       | 5.8 MB    | ##9        |  30%
# openssl-1.1.1h       | 5.8 MB    | ###        |  31%
# openssl-1.1.1h       | 5.8 MB    | ###2       |  32%
# openssl-1.1.1h       | 5.8 MB    | ###3       |  33%
# openssl-1.1.1h       | 5.8 MB    | ###4       |  34%
# openssl-1.1.1h       | 5.8 MB    | ###5       |  36%
# openssl-1.1.1h       | 5.8 MB    | ###6       |  37%
# openssl-1.1.1h       | 5.8 MB    | ###8       |  38%
# openssl-1.1.1h       | 5.8 MB    | ###9       |  39%
# openssl-1.1.1h       | 5.8 MB    | ####       |  40%
# openssl-1.1.1h       | 5.8 MB    | ####1      |  42%
# openssl-1.1.1h       | 5.8 MB    | ####2      |  43%
# openssl-1.1.1h       | 5.8 MB    | ####3      |  44%
# openssl-1.1.1h       | 5.8 MB    | ####5      |  45%
# openssl-1.1.1h       | 5.8 MB    | ####6      |  46%
# openssl-1.1.1h       | 5.8 MB    | ####7      |  47%
# openssl-1.1.1h       | 5.8 MB    | ####8      |  48%
# openssl-1.1.1h       | 5.8 MB    | ####9      |  49%
# openssl-1.1.1h       | 5.8 MB    | #####      |  51%
# openssl-1.1.1h       | 5.8 MB    | #####1     |  51%
# openssl-1.1.1h       | 5.8 MB    | #####2     |  52%
# openssl-1.1.1h       | 5.8 MB    | #####3     |  53%
# openssl-1.1.1h       | 5.8 MB    | #####4     |  55%
# openssl-1.1.1h       | 5.8 MB    | #####5     |  56%
# openssl-1.1.1h       | 5.8 MB    | #####7     |  58%
# openssl-1.1.1h       | 5.8 MB    | #####8     |  59%
# openssl-1.1.1h       | 5.8 MB    | #####9     |  60%
# openssl-1.1.1h       | 5.8 MB    | ######     |  61%
# openssl-1.1.1h       | 5.8 MB    | ######2    |  62%
# openssl-1.1.1h       | 5.8 MB    | ######3    |  63%
# openssl-1.1.1h       | 5.8 MB    | ######4    |  64%
# openssl-1.1.1h       | 5.8 MB    | ######6    |  66%
# openssl-1.1.1h       | 5.8 MB    | ######7    |  67%
# openssl-1.1.1h       | 5.8 MB    | ######8    |  68%
# openssl-1.1.1h       | 5.8 MB    | ######9    |  70%
# openssl-1.1.1h       | 5.8 MB    | #######1   |  71%
# openssl-1.1.1h       | 5.8 MB    | #######2   |  72%
# openssl-1.1.1h       | 5.8 MB    | #######3   |  73%
# openssl-1.1.1h       | 5.8 MB    | #######4   |  74%
# openssl-1.1.1h       | 5.8 MB    | #######5   |  76%
# openssl-1.1.1h       | 5.8 MB    | #######6   |  77%
# openssl-1.1.1h       | 5.8 MB    | #######7   |  78%
# openssl-1.1.1h       | 5.8 MB    | #######9   |  79%
# openssl-1.1.1h       | 5.8 MB    | ########1  |  81%
# openssl-1.1.1h       | 5.8 MB    | ########2  |  83%
# openssl-1.1.1h       | 5.8 MB    | ########3  |  84%
# openssl-1.1.1h       | 5.8 MB    | ########4  |  85%
# openssl-1.1.1h       | 5.8 MB    | ########6  |  86%
# openssl-1.1.1h       | 5.8 MB    | ########7  |  87%
# openssl-1.1.1h       | 5.8 MB    | ########8  |  89%
# openssl-1.1.1h       | 5.8 MB    | ########9  |  90%
# openssl-1.1.1h       | 5.8 MB    | #########1 |  91%
# openssl-1.1.1h       | 5.8 MB    | #########2 |  92%
# openssl-1.1.1h       | 5.8 MB    | #########4 |  95%
# openssl-1.1.1h       | 5.8 MB    | #########6 |  96%
# openssl-1.1.1h       | 5.8 MB    | #########7 |  98%
# openssl-1.1.1h       | 5.8 MB    | #########8 |  99%
# openssl-1.1.1h       | 5.8 MB    | ########## | 100%
# openssl-1.1.1h       | 5.8 MB    | ########## | 100%
#
# conda-4.10.1         | 2.9 MB    |            |   0%
# conda-4.10.1         | 2.9 MB    |            |   1%
# conda-4.10.1         | 2.9 MB    | 3          |   4%
# conda-4.10.1         | 2.9 MB    | 5          |   6%
# conda-4.10.1         | 2.9 MB    | 7          |   7%
# conda-4.10.1         | 2.9 MB    | #          |  11%
# conda-4.10.1         | 2.9 MB    | #3         |  13%
# conda-4.10.1         | 2.9 MB    | #5         |  16%
# conda-4.10.1         | 2.9 MB    | ##         |  20%
# conda-4.10.1         | 2.9 MB    | ##2        |  23%
# conda-4.10.1         | 2.9 MB    | ##4        |  25%
# conda-4.10.1         | 2.9 MB    | ##7        |  27%
# conda-4.10.1         | 2.9 MB    | ##9        |  29%
# conda-4.10.1         | 2.9 MB    | ###1       |  32%
# conda-4.10.1         | 2.9 MB    | ###4       |  34%
# conda-4.10.1         | 2.9 MB    | ###6       |  36%
#
# Note: you may need to restart the kernel to use updated packages.conda-4.10.1         | 2.9 MB    | ###9       |  40%
# conda-4.10.1         | 2.9 MB    | ####1      |  42%
# conda-4.10.1         | 2.9 MB    | ####4      |  44%
# conda-4.10.1         | 2.9 MB    | ####6      |  46%
# conda-4.10.1         | 2.9 MB    | ####8      |  48%
#
# conda-4.10.1         | 2.9 MB    | #####      |  51%
# conda-4.10.1         | 2.9 MB    | #####2     |  53%
# conda-4.10.1         | 2.9 MB    | #####4     |  55%
# conda-4.10.1         | 2.9 MB    | #####7     |  57%
# conda-4.10.1         | 2.9 MB    | #####9     |  59%
# conda-4.10.1         | 2.9 MB    | ######1    |  61%
# conda-4.10.1         | 2.9 MB    | ######3    |  64%
# conda-4.10.1         | 2.9 MB    | ######5    |  66%
# conda-4.10.1         | 2.9 MB    | ######7    |  68%
# conda-4.10.1         | 2.9 MB    | #######    |  70%
# conda-4.10.1         | 2.9 MB    | #######2   |  72%
# conda-4.10.1         | 2.9 MB    | #######4   |  74%
# conda-4.10.1         | 2.9 MB    | #######6   |  77%
# conda-4.10.1         | 2.9 MB    | #######8   |  79%
# conda-4.10.1         | 2.9 MB    | ########2  |  83%
# conda-4.10.1         | 2.9 MB    | ########5  |  86%
# conda-4.10.1         | 2.9 MB    | ########8  |  88%
# conda-4.10.1         | 2.9 MB    | #########  |  90%
# conda-4.10.1         | 2.9 MB    | #########2 |  92%
# conda-4.10.1         | 2.9 MB    | #########4 |  95%
# conda-4.10.1         | 2.9 MB    | #########7 |  97%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
# conda-4.10.1         | 2.9 MB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
pip install pywhatkit
# Out:
# Collecting pywhatkit
#   Downloading pywhatkit-4.1-py3-none-any.whl (9.1 kB)
# Collecting pyautogui
#   Downloading PyAutoGUI-0.9.52.tar.gz (55 kB)
# Requirement already satisfied: requests in c:\users\hp\anaconda3\lib\site-packages (from pywhatkit) (2.24.0)
# Requirement already satisfied: Pillow in c:\users\hp\anaconda3\lib\site-packages (from pywhatkit) (8.0.1)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
# Collecting pymsgbox
#   Downloading PyMsgBox-1.0.9.tar.gz (18 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting PyTweening>=1.0.1
#   Downloading PyTweening-1.0.3.zip (15 kB)
# Collecting pyscreeze>=0.1.21
#   Downloading PyScreeze-0.1.27.tar.gz (25 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# Collecting pygetwindow>=0.0.5
#   Downloading PyGetWindow-0.0.9.tar.gz (9.7 kB)
# Collecting mouseinfo
#   Downloading MouseInfo-0.1.3.tar.gz (10 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests->pywhatkit) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests->pywhatkit) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\hp\anaconda3\lib\site-packages (from requests->pywhatkit) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests->pywhatkit) (1.25.11)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from wikipedia->pywhatkit) (4.9.3)
# Collecting pyrect
#   Downloading PyRect-0.1.4.tar.gz (15 kB)
# Collecting pyperclip
#   Downloading pyperclip-1.8.2.tar.gz (20 kB)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia->pywhatkit) (2.0.1)
# Building wheels for collected packages: pyautogui, wikipedia, pymsgbox, PyTweening, pyscreeze, pygetwindow, mouseinfo, pyrect, pyperclip
#   Building wheel for pyautogui (setup.py): started
#   Building wheel for pyautogui (setup.py): finished with status 'done'
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.52-py3-none-any.whl size=35198 sha256=1b4156dbb649ee928ff24b42e35980e7a0105d7eb66a095780283b7f98499afa
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\4d\0d\6a\4258cb741835ea9ce7897652ae88272d3baf5cb1944c1984aa
#   Building wheel for wikipedia (setup.py): started
#   Building wheel for wikipedia (setup.py): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11689 sha256=8bd0c82848f9570d75d0762724fee921f5a4983357b54b8b03f66ab47ba34757
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\07\93\05\72c05349177dca2e0ba31a33ba4f7907606f7ddef303517c6a
#   Building wheel for pymsgbox (PEP 517): started
#   Building wheel for pymsgbox (PEP 517): finished with status 'done'
#   Created wheel for pymsgbox: filename=PyMsgBox-1.0.9-py3-none-any.whl size=7420 sha256=17cc2c8f4707518558b0e58a7ee3ff047014d07b257e49356b384667e54a2d32
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\91\28\0d\f4eb606d38276836237d6dc2abf094241e6db5682a126e0389
#   Building wheel for PyTweening (setup.py): started
#   Building wheel for PyTweening (setup.py): finished with status 'done'
#   Created wheel for PyTweening: filename=PyTweening-1.0.3-py3-none-any.whl size=3820 sha256=355d58740837592f4eb17d8183948237930657f6371c5bd6f2e82d88a8076524
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\e7\50\20\790fbd95739abfdf0348bef99d5cc0c7c2930a19a91f602ddc
#   Building wheel for pyscreeze (PEP 517): started
#   Building wheel for pyscreeze (PEP 517): finished with status 'done'
#   Created wheel for pyscreeze: filename=PyScreeze-0.1.27-py3-none-any.whl size=12864 sha256=927e28bcf184cfca695d38e7fedd730390abc3f69eb50e59b10717837120adb6
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\f7\91\eb\c0fa176c095c77460a579ef339f24a377474b041e5543d1a00
#   Building wheel for pygetwindow (setup.py): started
#   Building wheel for pygetwindow (setup.py): finished with status 'done'
#   Created wheel for pygetwindow: filename=PyGetWindow-0.0.9-py3-none-any.whl size=11084 sha256=305a77e9075967f2d970292d46424356b3a556d60bd8bcbbf17c2b8de5b8e928
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\91\e3\04\184bda98ec7f7d5f0ba1f372bcf7b3ba86325151ae1dd690fe
#   Building wheel for mouseinfo (setup.py): started
#   Building wheel for mouseinfo (setup.py): finished with status 'done'
#   Created wheel for mouseinfo: filename=MouseInfo-0.1.3-py3-none-any.whl size=10910 sha256=bae07dff1d7429b3fc00c1298a874191a5c0823a39e7a2b015dc5c3e3f66873a
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d1\72\fb\35f403de66285df8ecca7049bcc61bfb57aba0f76d1f08f7eb
#   Building wheel for pyrect (setup.py): started
#   Building wheel for pyrect (setup.py): finished with status 'done'
#   Created wheel for pyrect: filename=PyRect-0.1.4-py2.py3-none-any.whl size=9552 sha256=f46f5f6840fdaad8421ca558d00f42060df48d6b363b4a9ddd1a2858ccfcddc9
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\d1\e4\47\c62f8291b16b6df7e89ac885881ff71f35ca04c6e384251de9
#   Building wheel for pyperclip (setup.py): started
#   Building wheel for pyperclip (setup.py): finished with status 'done'
#   Created wheel for pyperclip: filename=pyperclip-1.8.2-py3-none-any.whl size=11112 sha256=756710d314dd0f9713ec79ec29824848ba8d86e8eaf0ad5be402c4cd98a3d3a0
#   Stored in directory: c:\users\hp\appdata\local\pip\cache\wheels\7f\1a\65\84ff8c386bec21fca6d220ea1f5498a0367883a78dd5ba6122
# Successfully built pyautogui wikipedia pymsgbox PyTweening pyscreeze pygetwindow mouseinfo pyrect pyperclip
# Installing collected packages: pymsgbox, PyTweening, pyscreeze, pyrect, pygetwindow, pyperclip, mouseinfo, pyautogui, wikipedia, pywhatkit
# Successfully installed PyTweening-1.0.3 mouseinfo-0.1.3 pyautogui-0.9.52 pygetwindow-0.0.9 pymsgbox-1.0.9 pyperclip-1.8.2 pyrect-0.1.4 pyscreeze-0.1.27 pywhatkit-4.1 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install wikipedia
# Out:
# Requirement already satisfied: wikipedia in c:\users\hp\anaconda3\lib\site-packages (1.4.0)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\hp\anaconda3\lib\site-packages (from wikipedia) (2.24.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\hp\anaconda3\lib\site-packages (from wikipedia) (4.9.3)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2020.6.20)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\users\hp\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyjokes
# Out:
# Collecting pyjokes
#   Downloading pyjokes-0.6.0-py2.py3-none-any.whl (26 kB)
# Installing collected packages: pyjokes
# Successfully installed pyjokes-0.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3
import datetime
import pywhatkit
import wikipedia
import pyjokes

listener = sr.Recognizer()
jarvis = pyttsx3.init()

voices = jarvis.getProperty('voices')
jarvis.setProperty('voice', voices[0].id)

def talk(text):
    jarvis.say(text)
    jarvis.runAndWait()

def take_command():
    
    try:
        with sr.Microphone() as source:
            print('I am listening boss, please speak...')
            talk('Yes boss, how can i help you?')
            voice = listener.listen(source)
            command = listener.recognize_google(voice)
            command = command.lower()
            if 'jarvis' in command:
                command = command.replace('jarvis', '')
    except:   
        pass
    return command
def run_jarvis():
    command = take_command()
    
    if 'time' in command:
        time = datetime.datetime.now().strftime('%I:%M %p')
        print('Current time is ' + time)
        talk('Current time is ' + time)
    elif 'play' in command:
        song = command.replace('play', '')
        talk('playing ' + song)
        pywhatkit.playonyt(song)
    elif 'tell me about' in command:
        wiki = command.replace('tell me about', '')
        info = wikipedia.summary(wiki, 2)
        print(info)
        talk(info)
    elif 'joke' in command:
        talk(pyjokes.get_joke())
    elif 'are you single' in command:
        talk('Sorry Sir, I am in a relationship with wifi')
    else:
        talk('Sorry I did not get your question, I can search it from google')
        pywhatkit.search(command)
             
        
run_jarvis()
# Out:
# I am listening boss, please speak...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-15-ee5a90f9a194> in <module>
#      55
#      56
# ---> 57 run_jarvis()
#
# <ipython-input-15-ee5a90f9a194> in run_jarvis()
#      31     return command
#      32 def run_jarvis():
# ---> 33     command = take_command()
#      34
#      35     if 'time' in command:
#
# <ipython-input-15-ee5a90f9a194> in take_command()
#      29     except:
#      30         pass
# ---> 31     return command
#      32 def run_jarvis():
#      33     command = take_command()
#
# UnboundLocalError: local variable 'command' referenced before assignment
